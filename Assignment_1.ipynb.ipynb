# %%
n=int(input("Enter a number :"))

count = 0
for i in range(1, n+1):
    if n%i ==0:
        count += 1
        
if count == 2:
    print("Prime number")
else:
    print("Not a Prime number")
    

import random

a= random.randint(1,10)
b= random.randint(1,10)

answer=int(input(f"What is the product of {a} and {b} ? :"))

if answer == a*b:
    print("Correct !")
    
else:
    print("Incorrect !")
    print("The Product of {a} and {b} is :", a*b)

for num in range (100,201):
    
    if num%2==0:
        print(f"Even : {num} squared = {num**2}")
    else:
        print(f"Odd : {num} squared = {num**2}")
        


days=int(input("Enter number of days stayed :"))
tests=int(input("Enter the number of tests done :"))
medicine_cost=int(input("Enter the cost of medicine :"))

room_bill=days*2000
tests_bill=tests*300
doctor_fee=1500

total_bill= room_bill + tests_bill + doctor_fee + medicine_cost

if total_bill > 10000:
    discount= total_bill*0.1
    
else:
    discount=0
    

print("\n-------HOSPITAL BILL SUMMARY-------")
print("Doctor Consultation Fee :",doctor_fee)
print("Total Room Charges :",room_bill)
print("Lab Test Bill :",tests_bill)
print("Total Medicine Cost :",medicine_cost)
print("Total Before Discount :",total_bill)
print("Discounted Amount:",discount)
print("Final Bill :",total_bill-discount)
# Out:
# Enter a number : 15
# Not a Prime number
# What is the product of 5 and 3 ? : 15
# Correct !
# Even : 100 squared = 10000
# Odd : 101 squared = 10201
# Even : 102 squared = 10404
# Odd : 103 squared = 10609
# Even : 104 squared = 10816
# Odd : 105 squared = 11025
# Even : 106 squared = 11236
# Odd : 107 squared = 11449
# Even : 108 squared = 11664
# Odd : 109 squared = 11881
# Even : 110 squared = 12100
# Odd : 111 squared = 12321
# Even : 112 squared = 12544
# Odd : 113 squared = 12769
# Even : 114 squared = 12996
# Odd : 115 squared = 13225
# Even : 116 squared = 13456
# Odd : 117 squared = 13689
# Even : 118 squared = 13924
# Odd : 119 squared = 14161
# Even : 120 squared = 14400
# Odd : 121 squared = 14641
# Even : 122 squared = 14884
# Odd : 123 squared = 15129
# Even : 124 squared = 15376
# Odd : 125 squared = 15625
# Even : 126 squared = 15876
# Odd : 127 squared = 16129
# Even : 128 squared = 16384
# Odd : 129 squared = 16641
# Even : 130 squared = 16900
# ...
