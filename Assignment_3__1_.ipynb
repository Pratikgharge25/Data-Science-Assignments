# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\NIKHIL\Downloads\data science assignment\data science assignment\sales_data_with_discounts.csv")

df.info()

df.describe()

df.columns

df.head()

num_col=df.select_dtypes(include=["int64","float64"]).columns
cat_col=df.select_dtypes(include=["object"]).columns

print("\n-----NUMERICAL D-TYPE-----")
print("Numerical Dtype :",num_col)

print("\n-----CATEGORICAL D-TYPE-----")
print("Categorical Dtype :",cat_col)

df[['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
       'Discount Amount', 'Net Sales Value']].mean()

df[['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
       'Discount Amount', 'Net Sales Value']].median()

df[['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
       'Discount Amount', 'Net Sales Value']].mode()

df[['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
       'Discount Amount', 'Net Sales Value']].std()

stats=pd.DataFrame({
    "Mean":df[num_col].mean(),
    "Median" :df[num_col].median(),
    "Mode" :df[num_col].mode().iloc[0],
    "Std Deviation" :df[num_col].std()
    })
print(stats)

import matplotlib.pyplot as plt

for col in num_col:
    plt.figure()
    plt.hist(df[col])
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

for col in num_col:
    plt.figure()
    plt.boxplot(df[col])
    plt.title(f"Box Plot of {col}")
    plt.ylabel(col)
    plt.show()
    
for col in cat_col:
    plt.figure(figsize=(8,4))
    df[col].value_counts().plot(kind="bar")
    plt.title(f"Categorical Distribution : {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB
#
# -----NUMERICAL D-TYPE-----
# ...

# %% [markdown]
# ## Conclusion
#
# The assignment successfully demonstrated descriptive statistics and data visualization techniques. Histograms, bar plots, and box plots helped analyze the data distribution and identify patterns and outliers effectively. Overall, the analysis provided meaningful insights into the dataset.
